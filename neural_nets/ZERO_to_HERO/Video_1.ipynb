# %%
# !pip install micrograd

# %%
import torch

# %%
z = torch.zeros((2,3), dtype= torch.int32)
z
# Out:
# tensor([[0, 0, 0],
#         [0, 0, 0]], dtype=torch.int32)

# %%
## simple NN with aggrgation

## NN: take I/P with 2 i/p nuerons and 1 o/p
## first node with mul
## second with add
## o/p is sub

# %%
import numpy as np

# %%
## inputs 
X = np.array([
    [1,2],
    [2,3]  ])
w = np.array([
    [1,1],
    [1,1]
])

z = np.dot(X, w)

# w2 = np.eye(1, dype = 'int32')
w2 = np.array([1,1])

y = np.dot(z, w2)
y

## the problem with numpy is it's hard to code for gradient so switch to micrograd
# Out:
# array([ 6, 10])
